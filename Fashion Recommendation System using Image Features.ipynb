# %%
import zipfile

# Ouvrir le fichier ZIP
with zipfile.ZipFile('C:\\Users\\user\\Downloads\\women-fashion (1).zip', 'r') as zip_ref:
    # Lister les fichiers contenus dans l'archive
    file_list = zip_ref.namelist()
    print(file_list)
# Out:
# ['women fashion/', '__MACOSX/._women fashion', 'women fashion/white knee-length dress with a fitted design and long sleeves.webp', '__MACOSX/women fashion/._white knee-length dress with a fitted design and long sleeves.webp', 'women fashion/short, white, sleeveless dress with thin straps.jpg', '__MACOSX/women fashion/._short, white, sleeveless dress with thin straps.jpg', 'women fashion/deep burgundy, silky dress with long sleeves and a wrap-style front.jpg', '__MACOSX/women fashion/._deep burgundy, silky dress with long sleeves and a wrap-style front.jpg', 'women fashion/long, intricately designed dress with full sleeves.jpg', '__MACOSX/women fashion/._long, intricately designed dress with full sleeves.jpg', 'women fashion/beige top adorned with black dots and a green skirt.jpg', '__MACOSX/women fashion/._beige top adorned with black dots and a green skirt.jpg', 'women fashion/form-fitting dress with a vibrant pattern of yellow, blue, and black.jpg', '__MACOSX/women fashion/._form-f
# ...

# %%
pip install pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import zipfile
from PIL import Image, UnidentifiedImageError
import io

# Ouvrir le fichier ZIP et parcourir les fichiers à l'intérieur
with zipfile.ZipFile('C:\\Users\\user\\Downloads\\women-fashion (1).zip', 'r') as zip_ref:
    # Obtenir la liste des fichiers dans le ZIP
    for file_name in zip_ref.namelist():
        # Filtrer les fichiers système (comme ceux de __MACOSX)
        if not file_name.startswith('__MACOSX') and (file_name.endswith('.jpg') or file_name.endswith('.png')):
            try:
                # Ouvrir l'image
                with zip_ref.open(file_name) as image_file:
                    image = Image.open(image_file)
                    image.show()  # Afficher l'image
                    print(f"Image: {file_name}, Taille: {image.size}")
            except UnidentifiedImageError:
                print(f"Le fichier {file_name} n'est pas une image valide.")
# Out:
# Image: women fashion/short, white, sleeveless dress with thin straps.jpg, Taille: (272, 408)
# Image: women fashion/deep burgundy, silky dress with long sleeves and a wrap-style front.jpg, Taille: (1080, 1440)
# Image: women fashion/long, intricately designed dress with full sleeves.jpg, Taille: (191, 263)
# Image: women fashion/beige top adorned with black dots and a green skirt.jpg, Taille: (731, 1024)
# Image: women fashion/form-fitting dress with a vibrant pattern of yellow, blue, and black.jpg, Taille: (199, 253)
# Image: women fashion/black top, white trousers.jpg, Taille: (236, 497)
# Image: women fashion/ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg, Taille: (600, 749)
# Image: women fashion/metallic-looking jacket with intricate designs and fringes hanging from the sleeves.jpg, Taille: (304, 403)
# Image: women fashion/anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg, Taille: (600, 800)
# ...

# %%
import os
from zipfile import ZipFile

# Chemin vers le fichier ZIP et le répertoire d'extraction
zip_file_path = 'C:\\Users\\user\\Downloads\\women-fashion (1).zip'
extraction_directory = 'C:\\Users\\user\\Downloads\\women_fashion\\'

# Créer le répertoire d'extraction s'il n'existe pas
if not os.path.exists(extraction_directory):
    os.makedirs(extraction_directory)

# Extraire les fichiers du fichier ZIP
with ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_directory)

# Lister les fichiers extraits dans le répertoire parent
extracted_files = os.listdir(extraction_directory)
print(f"Fichiers dans le répertoire d'extraction : {extracted_files}")

# Si 'women fashion' existe, mettre à jour le chemin
if 'women fashion' in extracted_files:
    extraction_directory_updated = os.path.join(extraction_directory, 'women fashion')
    
    # Lister les fichiers dans le répertoire mis à jour
    extracted_files_updated = os.listdir(extraction_directory_updated)
    print(f"Fichiers dans 'women fashion' : {extracted_files_updated[:10]}")
else:
    print("'women fashion' n'a pas été trouvé dans le répertoire d'extraction.")
# Out:
# Fichiers dans le répertoire d'extraction : ['women fashion', '__MACOSX']
# Fichiers dans 'women fashion' : ['.DS_Store', 'anarkali suit with a long, olive green kurta adorned with intricate embroidery around the neckline and cuffs, paired with matching fitted trousers.jpg', 'Anarkali suit with a modern twist.jpg', 'Anarkali suit with fitted bodice with a high neckline.jpg', 'anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg', 'anarkali suit with lavender in color with intricate white patterns throughout the fabric.jpg', 'anarkali suit. It consists of a turquoise skirt with detailed golden embroidery, a multicolored blouse with floral patterns, and an orange dupatta with lace borders.jpg', 'ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg', 'beige top adorned with black dots and a green skirt.jpg', 'black and white gingham checkered A-line dress with a flared skirt.jpg']

# %%
# correcting the path to include the 'women fashion' directory and listing its contents
extraction_directory_updated = os.path.join(extraction_directory, 'women fashion')

# list the files in the updated directory
extracted_files_updated = os.listdir(extraction_directory_updated)
extracted_files_updated[:10], len(extracted_files_updated)
# Out:
# (['.DS_Store',
#   'anarkali suit with a long, olive green kurta adorned with intricate embroidery around the neckline and cuffs, paired with matching fitted trousers.jpg',
#   'Anarkali suit with a modern twist.jpg',
#   'Anarkali suit with fitted bodice with a high neckline.jpg',
#   'anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg',
#   'anarkali suit with lavender in color with intricate white patterns throughout the fabric.jpg',
#   'anarkali suit. It consists of a turquoise skirt with detailed golden embroidery, a multicolored blouse with floral patterns, and an orange dupatta with lace borders.jpg',
#   'ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg',
#   'beige top adorned with black dots and a green skirt.jpg',
#   'black and white gingham checkered A-line dress with a flared skirt.jpg'],
#  97)

# %%
from PIL import Image, UnidentifiedImageError
import matplotlib.pyplot as plt
import os

# Fonction pour charger et afficher une image
def display_image(file_path):
    try:
        image = Image.open(file_path)
        plt.imshow(image)
        plt.axis('off')
        plt.show()
    except UnidentifiedImageError:
        print(f"Le fichier {file_path} n'est pas une image valide.")

# Filtrer et afficher la première image valide
for file_name in extracted_files_updated:
    # Vérifier si le fichier est une image en fonction de son extension
    if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
        first_image_path = os.path.join(extraction_directory_updated, file_name)
        display_image(first_image_path)
        break  # Affiche uniquement la première image valide

# %%
import glob

# directory path containing your images
image_directory = '/content/women_fashion/women fashion'

image_paths_list = [file for file in glob.glob(os.path.join(image_directory, '*.*')) if file.endswith(('.jpg', '.png', '.jpeg', 'webp'))]

# print the list of image file paths
print(image_paths_list)
# Out:
# []

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.models import Model
import numpy as np

base_model = VGG16(weights='imagenet', include_top=False)
model = Model(inputs=base_model.input, outputs=base_model.output)

def preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array_expanded = np.expand_dims(img_array, axis=0)
    return preprocess_input(img_array_expanded)

def extract_features(model, preprocessed_img):
    features = model.predict(preprocessed_img)
    flattened_features = features.flatten()
    normalized_features = flattened_features / np.linalg.norm(flattened_features)
    return normalized_features

all_features = []
all_image_names = []

for img_path in image_paths_list:
    preprocessed_img = preprocess_image(img_path)
    features = extract_features(model, preprocessed_img)
    all_features.append(features)
    all_image_names.append(os.path.basename(img_path))
# Out:
# ...
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 58s 1us/step

# %%
import os

# Chemin vers le dossier d'extraction
image_directory = 'C:\\Users\\user\\Downloads\\women_fashion\\women fashion'

# Lister tous les fichiers dans le répertoire
files_in_directory = os.listdir(image_directory)
print(files_in_directory)
# Out:
# ['.DS_Store', 'anarkali suit with a long, olive green kurta adorned with intricate embroidery around the neckline and cuffs, paired with matching fitted trousers.jpg', 'Anarkali suit with a modern twist.jpg', 'Anarkali suit with fitted bodice with a high neckline.jpg', 'anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg', 'anarkali suit with lavender in color with intricate white patterns throughout the fabric.jpg', 'anarkali suit. It consists of a turquoise skirt with detailed golden embroidery, a multicolored blouse with floral patterns, and an orange dupatta with lace borders.jpg', 'ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg', 'beige top adorned with black dots and a green skirt.jpg', 'black and white gingham checkered A-line dress with a flared skirt.jpg', 'black double-breasted blazer with gold buttons, paired with a mid-length skirt.jpg', 'black dress with lace detailing.jpg', 'black dress with sparkling deta
# ...

# %%
input_image_path = os.path.join(image_directory, 'elegant_dress.jpg')

# %%
input_image_path = 'C:\\Users\\user\\Downloads\\women_fashion\\women fashion\\dark, elegant, sleeveless dress that reaches down to about mid-calf.jpg'

# %%
import os

# Spécifier le chemin du répertoire
image_directory = 'C:\\Users\\user\\Downloads\\women_fashion\\women fashion'

# Lister les fichiers dans le répertoire
files_in_directory = os.listdir(image_directory)
print(files_in_directory)
# Out:
# ['.DS_Store', 'anarkali suit with a long, olive green kurta adorned with intricate embroidery around the neckline and cuffs, paired with matching fitted trousers.jpg', 'Anarkali suit with a modern twist.jpg', 'Anarkali suit with fitted bodice with a high neckline.jpg', 'anarkali suit with intricate silver embellishments on the neckline, sleeves.jpg', 'anarkali suit with lavender in color with intricate white patterns throughout the fabric.jpg', 'anarkali suit. It consists of a turquoise skirt with detailed golden embroidery, a multicolored blouse with floral patterns, and an orange dupatta with lace borders.jpg', 'ark green, knee-length dress with short sleeves and a white, patterned neckline.jpg', 'beige top adorned with black dots and a green skirt.jpg', 'black and white gingham checkered A-line dress with a flared skirt.jpg', 'black double-breasted blazer with gold buttons, paired with a mid-length skirt.jpg', 'black dress with lace detailing.jpg', 'black dress with sparkling deta
# ...

# %%
input_image_path = 'C:\\Users\\user\\Downloads\\women_fashion\\women fashion\\black top, white trousers.jpg'

# %%
recommend_fashion_items_cnn(input_image_path, all_features, image_paths_list, model, top_n=4)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
def recommend_fashion_items_cnn(input_image_path, all_features, all_image_names, model, top_n=5):
    # Prétraiter l'image d'entrée et extraire ses caractéristiques
    preprocessed_img = preprocess_image(input_image_path)
    input_features = extract_features(model, preprocessed_img)

    # Calculer les similarités (par exemple, en utilisant la distance cosinus)
    similarities = []
    for features in all_features:
        similarity = np.dot(input_features, features)  # Produit scalaire pour la similarité
        similarities.append(similarity)

    # Trouver les indices des images les plus similaires
    similar_indices = np.argsort(similarities)[-top_n-1:-1][::-1]  # Obtenir les indices des meilleures similarités, exclure l'image d'entrée

    # Afficher l'image d'entrée
    display_image(input_image_path)

    # Afficher les images recommandées
    for index in similar_indices:
        recommended_image_path = image_paths_list[index]
        display_image(recommended_image_path)

# %%
# Liste des chemins d'accès des images
image_paths_list = [os.path.join(extraction_directory_updated, filename) for filename in extracted_files_updated if filename.endswith(('.jpg', '.png'))]

# Liste des caractéristiques
all_features = []
for img_path in image_paths_list:
    preprocessed_img = preprocess_image(img_path)
    features = extract_features(model, preprocessed_img)
    all_features.append(features)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ...

# %%
input_image_path = 'C:\\Users\\user\\Downloads\\women_fashion\\women fashion\\black top, white trousers.jpg'
recommend_fashion_items_cnn(input_image_path, all_features, image_paths_list, model, top_n=4)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
